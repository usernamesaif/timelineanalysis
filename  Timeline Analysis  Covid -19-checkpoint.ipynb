# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Time Line Analysis : Covid-19

# %% [markdown]
# # Name - Saif Abbas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as colors
import random

# %%
import os
covid_data =("C:\\Users\\User\\Downloads\\owid-covid-data.csv")
os.path.exists(covid_data)
# Out:
# True

# %%
covid_data = pd.read_csv("C:\\Users\\User\\Downloads\\owid-covid-data.csv")
covid_data.head(20)
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1       AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2       AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3       AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4       AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 5       AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 6       AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# 7       AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 8       AFG      Asia  Afghanistan  2020-03-03          2.0        1.0
# 9       AFG      Asia  Afghanistan  2020-03-04          4.0        2.0
# 10      AFG      Asia  Afghanistan  2020-03-05          4.0        0.0
# 11      AFG      Asia  Afghanistan  2020-03-06          4.0        0.0
# ...

# %%
covid_data.shape
# Out:
# (69383, 59)

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69383 entries, 0 to 69382
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               69383 non-null  object
#  1   continent                              65920 non-null  object
#  2   location                               69383 non-null  object
#  3   date                                   69383 non-null  object
#  4   total_cases                            68545 non-null  float64
#  5   new_cases                              68543 non-null  float64
#  6   new_cases_smoothed                     67542 non-null  float64
#  7   total_deaths                           59598 non-null  float64
#  8   new_deaths                             59756 non-null  float64
#  9   new_deaths_smoothed                    67542 non-null  float64
# ...

# %%
covid_data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  6.854500e+04   68543.000000        67542.000000  5.959800e+04
# mean   5.653166e+05    5066.492421         5091.948714  1.740058e+04
# std    4.004632e+06   32206.819130        32002.991154  1.007811e+05
# min    1.000000e+00  -46076.000000        -1121.714000  1.000000e+00
# 25%    6.590000e+02       1.000000            5.429000  3.400000e+01
# 50%    7.025000e+03      55.000000           66.286000  2.230000e+02
# 75%    7.677600e+04     636.000000          661.393250  2.081750e+03
# max    1.095074e+08  858062.000000       738534.000000  2.418797e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  59756.000000         67542.000000             68169.000000
# mean     130.119553           113.769690              6602.011750
# std      716.696732           652.394248             13174.629445
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
covid_data.nunique()
# Out:
# iso_code                                   212
# continent                                    6
# location                                   212
# date                                       413
# total_cases                              35578
# new_cases                                 9628
# new_cases_smoothed                       18266
# total_deaths                             13436
# new_deaths                                2368
# new_deaths_smoothed                       5275
# total_cases_per_million                  52390
# new_cases_per_million                    30069
# new_cases_smoothed_per_million           33766
# total_deaths_per_million                 31359
# new_deaths_per_million                    6146
# new_deaths_smoothed_per_million           7297
# reproduction_rate                          357
# icu_patients                              1979
# icu_patients_per_million                  4046
# hosp_patients                             3767
# ...

# %%
covid_data.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3463
# location                                     0
# date                                         0
# total_cases                                838
# new_cases                                  840
# new_cases_smoothed                        1841
# total_deaths                              9785
# new_deaths                                9627
# new_deaths_smoothed                       1841
# total_cases_per_million                   1214
# new_cases_per_million                     1216
# new_cases_smoothed_per_million            2212
# total_deaths_per_million                 10148
# new_deaths_per_million                    9990
# new_deaths_smoothed_per_million           2212
# reproduction_rate                        13912
# icu_patients                             62066
# icu_patients_per_million                 62066
# hosp_patients                            60684
# ...

# %%
covid_data.continent.value_counts()[0:10]
# Out:
# Africa           18248
# Europe           16769
# Asia             16629
# North America     8124
# South America     4232
# Oceania           1918
# Name: continent, dtype: int64

# %%
dataset =covid_data[covid_data['date']*'2020-11-15']
dataset =dataset[-dataset['location'].isin(['word','international'])]
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
india = covid_data[covid_data["location"] == "India"]
india.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 28480      IND      Asia    India  2020-01-30          1.0        1.0
# 28481      IND      Asia    India  2020-01-31          1.0        0.0
# 28482      IND      Asia    India  2020-02-01          1.0        0.0
# 28483      IND      Asia    India  2020-02-02          2.0        1.0
# 28484      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 28480                 NaN           NaN         NaN                  NaN  ...
# 28481                 NaN           NaN         NaN                  NaN  ...
# 28482                 NaN           NaN         NaN                  NaN  ...
# 28483                 NaN           NaN         NaN                  NaN  ...
# 28484                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
india.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 28859      IND      Asia    India  2021-02-12   10892746.0    12143.0
# 28860      IND      Asia    India  2021-02-13   10904940.0    12194.0
# 28861      IND      Asia    India  2021-02-14   10916589.0    11649.0
# 28862      IND      Asia    India  2021-02-15   10925710.0     9121.0
# 28863      IND      Asia    India  2021-02-16   10937320.0    11610.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 28859           11206.000      155550.0       103.0               90.286  ...
# 28860           11225.286      155642.0        92.0               92.286  ...
# 28861           11199.286      155732.0        90.0               93.143  ...
# 28862           11200.857      155813.0        81.0               93.571  ...
# 28863           11278.429      155913.0       100.0               94.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data =india)
plt.show()

# %%
india_last_ten_days=india.tail(10)

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data =india_last_ten_days)
plt.show()

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data =india)
plt.show()

# %%
brazil=covid_data[covid_data["location"]=="Brazil"]
brazil.head(10)
# Out:
#      iso_code      continent location        date  total_cases  new_cases  \
# 8928      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 8929      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 8930      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 8931      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 8932      BRA  South America   Brazil  2020-03-01          2.0        0.0
# 8933      BRA  South America   Brazil  2020-03-02          2.0        0.0
# 8934      BRA  South America   Brazil  2020-03-03          2.0        0.0
# 8935      BRA  South America   Brazil  2020-03-04          4.0        2.0
# 8936      BRA  South America   Brazil  2020-03-05          4.0        0.0
# 8937      BRA  South America   Brazil  2020-03-06         13.0        9.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
brazil_last_ten_days=brazil.tail(10)

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data =brazil_last_ten_days)
plt.show()

# %%
germany_spain=covid_data[(covid_data["location"]=="Germany") |(covid_data["location"]=="spain")]

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.barplot(x="location",y="total_cases",data =germany_spain,hue="date" )
plt.show()

# %%
last_date_cases=covid_data[(covid_data["date"]=="2021-02-16")]
last_date_cases
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 358         AFG      Asia  Afghanistan  2021-02-16      55518.0        4.0
# 728    OWID_AFR       NaN       Africa  2021-02-16    3773094.0    10027.0
# 1086        ALB    Europe      Albania  2021-02-16      94651.0      801.0
# 1444        DZA    Africa      Algeria  2021-02-16     111069.0      175.0
# 1796        AND    Europe      Andorra  2021-02-16      10555.0       17.0
# ...         ...       ...          ...         ...          ...        ...
# 68007       VNM      Asia      Vietnam  2021-02-16       2311.0       42.0
# 68399  OWID_WRL       NaN        World  2021-02-16  109507408.0   350522.0
# 68712       YEM      Asia        Yemen  2021-02-16       2148.0        3.0
# 69048       ZMB    Africa       Zambia  2021-02-16      70823.0      575.0
# 69382       ZWE    Africa     Zimbabwe  2021-02-16      35315.0       93.0
#
# ...

# %%
maximum_cases_countary =last_date_cases.sort_values(by ="total_cases",ascending = False)
maximum_cases_countary
# Out:
#        iso_code      continent              location        date  total_cases  \
# 68399  OWID_WRL            NaN                 World  2021-02-16  109507408.0
# 21575  OWID_EUR            NaN                Europe  2021-02-16   32624041.0
# 45951  OWID_NAM            NaN         North America  2021-02-16   31864080.0
# 66149       USA  North America         United States  2021-02-16   27756624.0
# 3639   OWID_ASI            NaN                  Asia  2021-02-16   24182275.0
# ...         ...            ...                   ...         ...          ...
# 39560       MHL        Oceania      Marshall Islands  2021-02-16          4.0
# 53132       WSM        Oceania                 Samoa  2021-02-16          3.0
# 66928       VUT        Oceania               Vanuatu  2021-02-16          1.0
# 40676       FSM        Oceania  Micronesia (country)  2021-02-16          1.0
# 30695       IMN         Europe           Isle of Man  2021-02-16          NaN
#
# ...

# %% [markdown]
# # Top 10 Countary of Maximum Cases

# %%
maximum_cases_countary[1:11]
# Out:
#        iso_code      continent        location        date  total_cases  \
# 21575  OWID_EUR            NaN          Europe  2021-02-16   32624041.0
# 45951  OWID_NAM            NaN   North America  2021-02-16   31864080.0
# 66149       USA  North America   United States  2021-02-16   27756624.0
# 3639   OWID_ASI            NaN            Asia  2021-02-16   24182275.0
# 21966  OWID_EUN            NaN  European Union  2021-02-16   21222433.0
# 57855  OWID_SAM            NaN   South America  2021-02-16   17030908.0
# 28863       IND           Asia           India  2021-02-16   10937320.0
# 9284        BRA  South America          Brazil  2021-02-16    9921981.0
# 65757       GBR         Europe  United Kingdom  2021-02-16    4070332.0
# 51691       RUS         Europe          Russia  2021-02-16    4053535.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 21575   123071.0          128511.857      775517.0      4708.0
# ...

# %%
sns.barplot(x="location",y="total_cases",data = maximum_cases_countary[1:11],hue ="date")
plt.show()
